# %%
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random
#from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.data import build_detection_train_loader
from detectron2.data import build_detection_test_loader

from detectron2.engine import DefaultTrainer
from detectron2.engine import SimpleTrainer
from detectron2.engine import HookBase
from typing import Dict, List, Optional
import detectron2.solver as solver
import detectron2.modeling as modeler
import detectron2.data as data
import detectron2.data.transforms as T
import detectron2.checkpoint as checkpointer
from detectron2.data import detection_utils as utils
import weakref
import copy
import torch
import time

import imgaug.augmenters as iaa

from astrodet import astrodet as toolkit
from PIL import Image, ImageEnhance
from astropy.visualization import make_lupton_rgb
from astrodet.detectron import plot_stretch_Q
from detectron2.utils.file_io import PathManager
from iopath.common.file_io import file_lock

import logging
logger = logging.getLogger(__name__)
import shutil
import json

# %%
# Print the versions to test the imports and so we know what works
print(detectron2.__version__)
print(np.__version__)
print(cv2.__version__)
# Out:
# 0.6
# 1.20.3
# 4.5.3

# %%
# Prettify the plotting
from astrodet.astrodet import set_mpl_style
set_mpl_style()

# %%
#Todo: change the dirpath here
dirpath = '/home/shared/hsc/decam/decam_data/' # Path to dataset
output_dir = '/home/shared/hsc/decam/models/'

#dataset_names = ['train', 'test', 'val'] 
dataset_names = ['test']

# %%
from detectron2.structures import BoxMode
from astropy.io import fits
import glob

def get_astro_dicts(img_dir):
        
    # It's weird to call this img_dir
    set_dirs = sorted(glob.glob('%s/set_*' % img_dir))
    
    dataset_dicts = []
    
    # Loop through each set
    for idx, set_dir in enumerate(set_dirs):
        record = {}
        
        mask_dir = os.path.join(img_dir, set_dir, "masks.fits")
        filename = os.path.join(img_dir, set_dir, "img")
        
        # Open each FITS image
        with fits.open(mask_dir, memmap=False, lazy_load_hdus=False) as hdul:
            sources = len(hdul)
            height, width = hdul[0].data.shape
            data = [hdu.data/np.max(hdu.data) for hdu in hdul]
            category_ids = [hdu.header["CLASS_ID"] for hdu in hdul]
            
        record["file_name"] = filename
        record["image_id"] = idx
        record["height"] = height
        record["width"] = width
        objs = []
        
        # Mask value thresholds per category_id
        thresh = [0.005 if i == 1 else 0.08 for i in category_ids]
        
        # Generate segmentation masks
        for i in range(sources):
            image = data[i]
            mask = np.zeros([height, width], dtype=np.uint8)
            # Create mask from threshold
            mask[:,:][image > thresh[i]] = 1
            # Smooth mask
            mask[:,:] = cv2.GaussianBlur(mask[:,:], (9,9), 2)
            
            # https://github.com/facebookresearch/Detectron/issues/100
            contours, hierarchy = cv2.findContours((mask).astype(np.uint8), cv2.RETR_TREE,
                                                        cv2.CHAIN_APPROX_SIMPLE)
            segmentation = []
            for contour in contours:
                x,y,w,h = cv2.boundingRect(contour)
                contour = contour.flatten().tolist()
                # segmentation.append(contour)
                if len(contour) > 4:
                    segmentation.append(contour)
            # No valid countors
            if len(segmentation) == 0:
                continue
            
            # Add to dict
            obj = {
                "bbox": [x, y, w, h],
                "area": w*h,
                "bbox_mode": BoxMode.XYWH_ABS,
                "segmentation": segmentation,
                "category_id": category_ids[i] - 1,
            }
            objs.append(obj)
            
        record["annotations"] = objs
        dataset_dicts.append(record)
         
    return dataset_dicts


for i, d in enumerate(dataset_names):
    filenames_dir = os.path.join(dirpath,d)
    DatasetCatalog.register("astro_" + d, lambda: get_astro_dicts(filenames_dir))
    MetadataCatalog.get("astro_" + d).set(thing_classes=["star", "galaxy"], things_colors = ['blue', 'gray'])
astro_metadata = MetadataCatalog.get("astro_train")

# %%
def convert_to_json(dict_list, name, output_file, allow_cached=True):
    """
    Converts dataset into COCO format and saves it to a json file.
    dataset_name must be registered in DatasetCatalog and in detectron2's standard format.

    Args:
        dataset_name:
            reference from the config file to the catalogs
            must be registered in DatasetCatalog and in detectron2's standard format
        output_file: path of json file that will be saved to
        allow_cached: if json file is already present then skip conversion
    """

    # TODO: The dataset or the conversion script *may* change,
    # a checksum would be useful for validating the cached data

    PathManager.mkdirs(os.path.dirname(output_file))
    with file_lock(output_file):
        if PathManager.exists(output_file) and allow_cached:
            logger.warning(
                f"Using previously cached COCO format annotations at '{output_file}'. "
                "You need to clear the cache file if your dataset has been modified."
            )
        else:            

            print(f"Caching COCO format annotations at '{output_file}' ...")
            tmp_file = output_file + ".tmp"
            with PathManager.open(tmp_file, "w") as f:
                json.dump(dict_list, f)
            shutil.move(tmp_file, output_file)

# %%
t0 = time.time()
dataset_dicts = {}
for i, d in enumerate(dataset_names):
    print(f'Loading {d}')
    dataset_dicts[d] = get_astro_dicts(os.path.join(dirpath, d))
    
print('Took ', time.time()-t0, 'seconds for ', sampleNumbers, ' samples')
# Out:
# Loading test
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3024651/1291663734.py in <cell line: 7>()
#       5     dataset_dicts[d] = get_astro_dicts(os.path.join(dirpath, d))
#       6
# ----> 7 print('Took ', time.time()-t0, 'seconds for ', sampleNumbers, ' samples')
#
# NameError: name 'sampleNumbers' is not defined

# %%
dataset_dicts['train'][0]
# Out:
# {'file_name': '/home/shared/hsc/decam/decam_data/train/set_0/img',
#  'image_id': 0,
#  'height': 512,
#  'width': 512,
#  'annotations': [{'bbox': [361, 145, 18, 16],
#    'area': 288,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[366,
#      145,
#      365,
#      146,
#      364,
#      146,
#      362,
#      148,
#      362,
#      149,
#      361,
#      150,
#      361,
#      152,
#      362,
#      153,
#      362,
#      154,
#      364,
#      156,
#      364,
#      157,
#      365,
#      158,
#      366,
#      158,
#      367,
#      159,
#      368,
#      159,
#      369,
#      160,
#      372,
#      160,
#      374,
#      158,
#      375,
#      158,
#      377,
#      156,
#      377,
#      155,
#      378,
#      154,
#      378,
#      149,
#      377,
#      148,
#      377,
#      147,
#      376,
#      147,
#      374,
#      145]],
#    'category_id': 1},
#   {'bbox': [294, 172, 10, 11],
#    'area': 110,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[299,
#      172,
#      298,
#      173,
#      296,
#      173,
#      294,
#      175,
#      294,
#      179,
#      297,
#      182,
#      299,
#      182,
#      300,
#      181,
#      301,
#      181,
#      303,
#      179,
#      303,
#      175,
#      301,
#      173,
#      300,
#      173]],
#    'category_id': 1},
#   {'bbox': [0, 342, 20, 19],
#    'area': 380,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[7,
#      342,
#      6,
#      343,
#      3,
#      343,
#      2,
#      344,
#      0,
#      344,
#      0,
#      359,
#      5,
#      359,
#      6,
#      360,
#      12,
#      360,
#      13,
#      359,
#      14,
#      359,
#      15,
#      358,
#      16,
#      358,
#      18,
#      356,
#      18,
#      355,
#      19,
#      354,
#      19,
#      350,
#      18,
#      349,
#      18,
#      348,
#      17,
#      347,
#      17,
#      346,
#      16,
#      345,
#      15,
#      345,
#      14,
#      344,
#      13,
#      344,
#      12,
#      343,
#      11,
#      343,
#      10,
#      342]],
#    'category_id': 1},
#   {'bbox': [64, 207, 9, 9],
#    'area': 81,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[66,
#      207,
#      65,
#      208,
#      65,
#      209,
#      64,
#      210,
#      64,
#      213,
#      66,
#      215,
#      69,
#      215,
#      70,
#      214,
#      71,
#      214,
#      72,
#      213,
#      72,
#      209,
#      70,
#      207]],
#    'category_id': 0},
#   {'bbox': [50, 372, 10, 10],
#    'area': 100,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[54,
#      372,
#      53,
#      373,
#      52,
#      373,
#      50,
#      375,
#      50,
#      379,
#      51,
#      380,
#      53,
#      380,
#      54,
#      381,
#      55,
#      381,
#      56,
#      380,
#      57,
#      380,
#      58,
#      379,
#      58,
#      377,
#      59,
#      376,
#      59,
#      375,
#      56,
#      372]],
#    'category_id': 1},
#   {'bbox': [447, 396, 11, 10],
#    'area': 110,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[450,
#      396,
#      449,
#      397,
#      448,
#      397,
#      447,
#      398,
#      447,
#      402,
#      448,
#      403,
#      448,
#      404,
#      449,
#      404,
#      450,
#      405,
#      455,
#      405,
#      457,
#      403,
#      457,
#      399,
#      456,
#      398,
#      456,
#      397,
#      455,
#      397,
#      454,
#      396]],
#    'category_id': 1},
#   {'bbox': [211, 308, 10, 10],
#    'area': 100,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[216,
#      308,
#      215,
#      309,
#      213,
#      309,
#      212,
#      310,
#      212,
#      311,
#      211,
#      312,
#      211,
#      313,
#      212,
#      314,
#      212,
#      315,
#      214,
#      317,
#      218,
#      317,
#      220,
#      315,
#      220,
#      311,
#      217,
#      308]],
#    'category_id': 0},
#   {'bbox': [293, 285, 10, 10],
#    'area': 100,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[297,
#      285,
#      296,
#      286,
#      295,
#      286,
#      293,
#      288,
#      293,
#      291,
#      296,
#      294,
#      299,
#      294,
#      302,
#      291,
#      302,
#      287,
#      301,
#      286,
#      300,
#      286,
#      299,
#      285]],
#    'category_id': 0},
#   {'bbox': [70, 24, 8, 6],
#    'area': 48,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[72,
#      24,
#      70,
#      26,
#      70,
#      27,
#      72,
#      29,
#      74,
#      29,
#      75,
#      28,
#      76,
#      28,
#      77,
#      27,
#      77,
#      25,
#      76,
#      24]],
#    'category_id': 1},
#   {'bbox': [72, 240, 11, 11],
#    'area': 121,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[76,
#      240,
#      75,
#      241,
#      74,
#      241,
#      74,
#      242,
#      72,
#      244,
#      72,
#      247,
#      73,
#      248,
#      73,
#      249,
#      74,
#      249,
#      75,
#      250,
#      78,
#      250,
#      79,
#      249,
#      80,
#      249,
#      81,
#      248,
#      81,
#      247,
#      82,
#      246,
#      82,
#      243,
#      81,
#      242,
#      81,
#      241,
#      80,
#      241,
#      79,
#      240]],
#    'category_id': 1},
#   {'bbox': [389, 146, 10, 10],
#    'area': 100,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[392,
#      146,
#      389,
#      149,
#      389,
#      151,
#      390,
#      152,
#      390,
#      153,
#      392,
#      155,
#      394,
#      155,
#      395,
#      154,
#      396,
#      154,
#      396,
#      153,
#      397,
#      152,
#      397,
#      150,
#      398,
#      149,
#      397,
#      148,
#      397,
#      147,
#      396,
#      146]],
#    'category_id': 1},
#   {'bbox': [343, 295, 11, 11],
#    'area': 121,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[347,
#      295,
#      346,
#      296,
#      345,
#      296,
#      344,
#      297,
#      344,
#      298,
#      343,
#      299,
#      343,
#      301,
#      344,
#      302,
#      344,
#      303,
#      346,
#      305,
#      351,
#      305,
#      353,
#      303,
#      353,
#      298,
#      351,
#      296,
#      349,
#      296,
#      348,
#      295]],
#    'category_id': 1},
#   {'bbox': [504, 305, 8, 23],
#    'area': 184,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[509,
#      305,
#      507,
#      307,
#      507,
#      308,
#      506,
#      309,
#      506,
#      310,
#      504,
#      312,
#      504,
#      321,
#      505,
#      322,
#      505,
#      323,
#      507,
#      325,
#      507,
#      326,
#      508,
#      327,
#      511,
#      327,
#      511,
#      305]],
#    'category_id': 1},
#   {'bbox': [461, 34, 9, 9],
#    'area': 81,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[463,
#      34,
#      461,
#      36,
#      461,
#      40,
#      463,
#      42,
#      467,
#      42,
#      469,
#      40,
#      469,
#      36,
#      467,
#      34]],
#    'category_id': 0},
#   {'bbox': [264, 304, 11, 12],
#    'area': 132,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[268,
#      304,
#      267,
#      305,
#      266,
#      305,
#      264,
#      307,
#      264,
#      309,
#      265,
#      310,
#      265,
#      312,
#      268,
#      315,
#      269,
#      315,
#      270,
#      314,
#      271,
#      314,
#      272,
#      313,
#      273,
#      313,
#      273,
#      312,
#      274,
#      311,
#      274,
#      308,
#      273,
#      307,
#      273,
#      306,
#      272,
#      305,
#      271,
#      305,
#      270,
#      304]],
#    'category_id': 1},
#   {'bbox': [429, 77, 15, 16],
#    'area': 240,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[436,
#      77,
#      435,
#      78,
#      434,
#      78,
#      433,
#      79,
#      432,
#      79,
#      430,
#      81,
#      430,
#      82,
#      429,
#      83,
#      429,
#      87,
#      430,
#      88,
#      430,
#      90,
#      432,
#      92,
#      439,
#      92,
#      440,
#      91,
#      441,
#      91,
#      443,
#      89,
#      443,
#      82,
#      442,
#      81,
#      442,
#      80,
#      441,
#      79,
#      440,
#      79,
#      439,
#      78,
#      438,
#      78,
#      437,
#      77]],
#    'category_id': 1},
#   {'bbox': [0, 327, 4, 11],
#    'area': 44,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[0, 327, 0, 337, 3, 334, 3, 330, 2, 329, 2, 328, 1, 327]],
#    'category_id': 1},
#   {'bbox': [379, 379, 9, 10],
#    'area': 90,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[382,
#      379,
#      381,
#      380,
#      380,
#      380,
#      379,
#      381,
#      379,
#      386,
#      381,
#      388,
#      385,
#      388,
#      387,
#      386,
#      387,
#      382,
#      384,
#      379]],
#    'category_id': 1},
#   {'bbox': [230, 115, 9, 10],
#    'area': 90,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[232,
#      115,
#      230,
#      117,
#      230,
#      121,
#      233,
#      124,
#      236,
#      124,
#      238,
#      122,
#      238,
#      119,
#      237,
#      118,
#      237,
#      117,
#      235,
#      115]],
#    'category_id': 1},
#   {'bbox': [0, 482, 6, 11],
#    'area': 66,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[0, 482, 0, 492, 5, 487, 5, 486, 1, 482]],
#    'category_id': 1},
#   {'bbox': [38, 228, 10, 11],
#    'area': 110,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[41,
#      228,
#      39,
#      230,
#      39,
#      231,
#      38,
#      232,
#      38,
#      235,
#      40,
#      237,
#      41,
#      237,
#      42,
#      238,
#      44,
#      238,
#      45,
#      237,
#      46,
#      237,
#      47,
#      236,
#      47,
#      231,
#      46,
#      230,
#      46,
#      229,
#      45,
#      228]],
#    'category_id': 1},
#   {'bbox': [343, 469, 13, 12],
#    'area': 156,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[346,
#      469,
#      343,
#      472,
#      343,
#      477,
#      346,
#      480,
#      351,
#      480,
#      352,
#      479,
#      353,
#      479,
#      354,
#      478,
#      354,
#      476,
#      355,
#      475,
#      355,
#      474,
#      354,
#      473,
#      354,
#      472,
#      351,
#      469]],
#    'category_id': 1},
#   {'bbox': [300, 143, 13, 10],
#    'area': 130,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[301,
#      143,
#      301,
#      144,
#      300,
#      145,
#      301,
#      146,
#      301,
#      147,
#      302,
#      148,
#      302,
#      149,
#      304,
#      151,
#      305,
#      151,
#      306,
#      152,
#      311,
#      152,
#      312,
#      151,
#      312,
#      149,
#      311,
#      148,
#      311,
#      147,
#      309,
#      145,
#      308,
#      145,
#      307,
#      144,
#      306,
#      144,
#      305,
#      143]],
#    'category_id': 1},
#   {'bbox': [80, 308, 8, 7],
#    'area': 56,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[82,
#      308,
#      81,
#      309,
#      81,
#      310,
#      80,
#      311,
#      81,
#      312,
#      81,
#      313,
#      82,
#      314,
#      86,
#      314,
#      87,
#      313,
#      87,
#      309,
#      86,
#      308]],
#    'category_id': 1},
#   {'bbox': [77, 279, 10, 10],
#    'area': 100,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[81,
#      279,
#      80,
#      280,
#      79,
#      280,
#      78,
#      281,
#      78,
#      282,
#      77,
#      283,
#      77,
#      284,
#      78,
#      285,
#      78,
#      286,
#      80,
#      288,
#      84,
#      288,
#      86,
#      286,
#      86,
#      282,
#      84,
#      280,
#      83,
#      280,
#      82,
#      279]],
#    'category_id': 0},
#   {'bbox': [112, 365, 13, 12],
#    'area': 156,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[115,
#      365,
#      113,
#      367,
#      113,
#      368,
#      112,
#      369,
#      112,
#      371,
#      113,
#      372,
#      113,
#      373,
#      115,
#      375,
#      116,
#      375,
#      117,
#      376,
#      119,
#      376,
#      120,
#      375,
#      121,
#      375,
#      123,
#      373,
#      123,
#      372,
#      124,
#      371,
#      123,
#      370,
#      123,
#      368,
#      122,
#      367,
#      121,
#      367,
#      120,
#      366,
#      118,
#      366,
#      117,
#      365]],
#    'category_id': 1},
#   {'bbox': [276, 0, 11, 7],
#    'area': 77,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[276,
#      0,
#      276,
#      4,
#      278,
#      6,
#      283,
#      6,
#      284,
#      5,
#      285,
#      5,
#      285,
#      3,
#      286,
#      2,
#      286,
#      0]],
#    'category_id': 1},
#   {'bbox': [496, 413, 9, 10],
#    'area': 90,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[499,
#      413,
#      498,
#      414,
#      497,
#      414,
#      497,
#      415,
#      496,
#      416,
#      496,
#      419,
#      497,
#      420,
#      497,
#      421,
#      498,
#      421,
#      499,
#      422,
#      501,
#      422,
#      502,
#      421,
#      503,
#      421,
#      503,
#      420,
#      504,
#      419,
#      504,
#      415,
#      502,
#      413]],
#    'category_id': 1},
#   {'bbox': [59, 64, 11, 11],
#    'area': 121,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[63,
#      64,
#      62,
#      65,
#      60,
#      65,
#      59,
#      66,
#      59,
#      70,
#      60,
#      71,
#      60,
#      72,
#      62,
#      74,
#      67,
#      74,
#      68,
#      73,
#      68,
#      72,
#      69,
#      71,
#      69,
#      69,
#      68,
#      68,
#      68,
#      67,
#      66,
#      65,
#      64,
#      65]],
#    'category_id': 1},
#   {'bbox': [76, 51, 10, 10],
#    'area': 100,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[78,
#      51,
#      76,
#      53,
#      76,
#      57,
#      79,
#      60,
#      81,
#      60,
#      82,
#      59,
#      83,
#      59,
#      84,
#      58,
#      84,
#      57,
#      85,
#      56,
#      85,
#      54,
#      82,
#      51]],
#    'category_id': 0},
#   {'bbox': [296, 158, 15, 14],
#    'area': 210,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[302,
#      158,
#      301,
#      159,
#      300,
#      159,
#      297,
#      162,
#      297,
#      163,
#      296,
#      164,
#      296,
#      167,
#      297,
#      168,
#      297,
#      169,
#      299,
#      171,
#      303,
#      171,
#      304,
#      170,
#      306,
#      170,
#      310,
#      166,
#      310,
#      161,
#      309,
#      160,
#      309,
#      159,
#      308,
#      158]],
#    'category_id': 1},
#   {'bbox': [233, 43, 14, 16],
#    'area': 224,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[238,
#      43,
#      237,
#      44,
#      236,
#      44,
#      233,
#      47,
#      233,
#      53,
#      237,
#      57,
#      238,
#      57,
#      239,
#      58,
#      241,
#      58,
#      243,
#      56,
#      244,
#      56,
#      245,
#      55,
#      245,
#      53,
#      246,
#      52,
#      246,
#      48,
#      245,
#      47,
#      245,
#      46,
#      242,
#      43]],
#    'category_id': 1},
#   {'bbox': [342, 405, 14, 14],
#    'area': 196,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[347,
#      405,
#      346,
#      406,
#      345,
#      406,
#      343,
#      408,
#      343,
#      409,
#      342,
#      410,
#      342,
#      413,
#      343,
#      414,
#      343,
#      415,
#      346,
#      418,
#      351,
#      418,
#      352,
#      417,
#      353,
#      417,
#      355,
#      415,
#      355,
#      411,
#      354,
#      410,
#      354,
#      409,
#      351,
#      406,
#      350,
#      406,
#      349,
#      405]],
#    'category_id': 1},
#   {'bbox': [86, 154, 11, 11],
#    'area': 121,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[91,
#      154,
#      90,
#      155,
#      89,
#      155,
#      87,
#      157,
#      87,
#      158,
#      86,
#      159,
#      87,
#      160,
#      87,
#      161,
#      89,
#      163,
#      90,
#      163,
#      91,
#      164,
#      93,
#      164,
#      94,
#      163,
#      95,
#      163,
#      95,
#      162,
#      96,
#      161,
#      96,
#      156,
#      94,
#      154]],
#    'category_id': 1},
#   {'bbox': [162, 288, 14, 18],
#    'area': 252,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[167,
#      288,
#      166,
#      289,
#      165,
#      289,
#      164,
#      290,
#      164,
#      291,
#      163,
#      292,
#      163,
#      293,
#      162,
#      294,
#      162,
#      299,
#      163,
#      300,
#      163,
#      302,
#      166,
#      305,
#      170,
#      305,
#      173,
#      302,
#      173,
#      301,
#      174,
#      300,
#      174,
#      298,
#      175,
#      297,
#      175,
#      295,
#      174,
#      294,
#      174,
#      293,
#      173,
#      292,
#      173,
#      291,
#      170,
#      288]],
#    'category_id': 1},
#   {'bbox': [127, 344, 11, 11],
#    'area': 121,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[131,
#      344,
#      128,
#      347,
#      128,
#      348,
#      127,
#      349,
#      128,
#      350,
#      128,
#      351,
#      131,
#      354,
#      134,
#      354,
#      136,
#      352,
#      136,
#      351,
#      137,
#      350,
#      137,
#      347,
#      134,
#      344]],
#    'category_id': 1},
#   {'bbox': [284, 372, 13, 12],
#    'area': 156,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[287,
#      372,
#      284,
#      375,
#      284,
#      378,
#      289,
#      383,
#      293,
#      383,
#      295,
#      381,
#      295,
#      379,
#      296,
#      378,
#      296,
#      377,
#      295,
#      376,
#      295,
#      374,
#      293,
#      372]],
#    'category_id': 1},
#   {'bbox': [23, 194, 10, 11],
#    'area': 110,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[24,
#      194,
#      24,
#      195,
#      23,
#      196,
#      23,
#      201,
#      26,
#      204,
#      28,
#      204,
#      29,
#      203,
#      30,
#      203,
#      31,
#      202,
#      31,
#      201,
#      32,
#      200,
#      32,
#      197,
#      31,
#      196,
#      31,
#      195,
#      30,
#      195,
#      29,
#      194]],
#    'category_id': 1},
#   {'bbox': [255, 191, 9, 9],
#    'area': 81,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[257,
#      191,
#      255,
#      193,
#      255,
#      197,
#      257,
#      199,
#      261,
#      199,
#      263,
#      197,
#      263,
#      193,
#      262,
#      192,
#      261,
#      192,
#      260,
#      191]],
#    'category_id': 1},
#   {'bbox': [17, 174, 19, 19],
#    'area': 361,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[24,
#      174,
#      23,
#      175,
#      21,
#      175,
#      19,
#      177,
#      19,
#      178,
#      18,
#      179,
#      18,
#      180,
#      17,
#      181,
#      17,
#      185,
#      18,
#      186,
#      18,
#      187,
#      20,
#      189,
#      21,
#      189,
#      22,
#      190,
#      23,
#      190,
#      24,
#      191,
#      26,
#      191,
#      27,
#      192,
#      31,
#      192,
#      32,
#      191,
#      33,
#      191,
#      34,
#      190,
#      34,
#      189,
#      35,
#      188,
#      35,
#      179,
#      34,
#      178,
#      34,
#      177,
#      33,
#      177,
#      31,
#      175,
#      30,
#      175,
#      29,
#      174]],
#    'category_id': 1},
#   {'bbox': [274, 115, 12, 12],
#    'area': 144,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[280,
#      115,
#      279,
#      116,
#      277,
#      116,
#      274,
#      119,
#      274,
#      122,
#      275,
#      123,
#      275,
#      124,
#      276,
#      125,
#      277,
#      125,
#      278,
#      126,
#      280,
#      126,
#      281,
#      125,
#      282,
#      125,
#      284,
#      123,
#      284,
#      122,
#      285,
#      121,
#      285,
#      120,
#      284,
#      119,
#      284,
#      118,
#      282,
#      116,
#      281,
#      116]],
#    'category_id': 1},
#   {'bbox': [367, 446, 10, 10],
#    'area': 100,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[371,
#      446,
#      370,
#      447,
#      369,
#      447,
#      368,
#      448,
#      368,
#      449,
#      367,
#      450,
#      367,
#      451,
#      368,
#      452,
#      368,
#      453,
#      370,
#      455,
#      373,
#      455,
#      374,
#      454,
#      375,
#      454,
#      375,
#      453,
#      376,
#      452,
#      376,
#      449,
#      375,
#      448,
#      375,
#      447,
#      374,
#      447,
#      373,
#      446]],
#    'category_id': 0},
#   {'bbox': [389, 203, 8, 7],
#    'area': 56,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[391,
#      203,
#      389,
#      205,
#      389,
#      208,
#      390,
#      208,
#      391,
#      209,
#      392,
#      209,
#      393,
#      208,
#      394,
#      208,
#      395,
#      207,
#      395,
#      206,
#      396,
#      205,
#      395,
#      204,
#      395,
#      203]],
#    'category_id': 1},
#   {'bbox': [142, 431, 10, 10],
#    'area': 100,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[145,
#      431,
#      143,
#      433,
#      143,
#      434,
#      142,
#      435,
#      142,
#      437,
#      144,
#      439,
#      145,
#      439,
#      146,
#      440,
#      147,
#      440,
#      148,
#      439,
#      149,
#      439,
#      151,
#      437,
#      151,
#      434,
#      148,
#      431]],
#    'category_id': 1},
#   {'bbox': [337, 435, 8, 8],
#    'area': 64,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[341,
#      435,
#      340,
#      436,
#      339,
#      436,
#      339,
#      437,
#      338,
#      438,
#      338,
#      439,
#      337,
#      440,
#      338,
#      441,
#      338,
#      442,
#      343,
#      442,
#      344,
#      441,
#      344,
#      437,
#      342,
#      435]],
#    'category_id': 1},
#   {'bbox': [126, 398, 10, 11],
#    'area': 110,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[130,
#      398,
#      127,
#      401,
#      127,
#      402,
#      126,
#      403,
#      126,
#      405,
#      127,
#      406,
#      127,
#      407,
#      128,
#      407,
#      129,
#      408,
#      132,
#      408,
#      135,
#      405,
#      135,
#      401,
#      134,
#      400,
#      134,
#      399,
#      133,
#      399,
#      132,
#      398]],
#    'category_id': 1},
#   {'bbox': [108, 460, 10, 10],
#    'area': 100,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[109,
#      460,
#      108,
#      461,
#      108,
#      466,
#      110,
#      468,
#      111,
#      468,
#      112,
#      469,
#      113,
#      469,
#      114,
#      468,
#      115,
#      468,
#      116,
#      467,
#      116,
#      466,
#      117,
#      465,
#      117,
#      462,
#      115,
#      460]],
#    'category_id': 1},
#   {'bbox': [19, 0, 15, 7],
#    'area': 105,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[19,
#      0,
#      19,
#      2,
#      21,
#      4,
#      22,
#      4,
#      23,
#      5,
#      24,
#      5,
#      25,
#      6,
#      29,
#      6,
#      33,
#      2,
#      33,
#      0]],
#    'category_id': 1},
#   {'bbox': [201, 272, 12, 13],
#    'area': 156,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[205,
#      272,
#      204,
#      273,
#      203,
#      273,
#      201,
#      275,
#      201,
#      281,
#      203,
#      283,
#      204,
#      283,
#      205,
#      284,
#      208,
#      284,
#      211,
#      281,
#      211,
#      280,
#      212,
#      279,
#      212,
#      277,
#      211,
#      276,
#      211,
#      275,
#      209,
#      273,
#      208,
#      273,
#      207,
#      272]],
#    'category_id': 1},
#   {'bbox': [456, 373, 10, 9],
#    'area': 90,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[458,
#      373,
#      457,
#      374,
#      457,
#      375,
#      456,
#      376,
#      456,
#      377,
#      457,
#      378,
#      457,
#      379,
#      459,
#      381,
#      463,
#      381,
#      465,
#      379,
#      465,
#      375,
#      463,
#      373]],
#    'category_id': 0},
#   {'bbox': [14, 8, 11, 11],
#    'area': 121,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[17,
#      8,
#      15,
#      10,
#      15,
#      11,
#      14,
#      12,
#      14,
#      13,
#      15,
#      14,
#      15,
#      15,
#      17,
#      17,
#      18,
#      17,
#      19,
#      18,
#      23,
#      18,
#      24,
#      17,
#      24,
#      11,
#      23,
#      10,
#      22,
#      10,
#      21,
#      9,
#      20,
#      9,
#      19,
#      8]],
#    'category_id': 1},
#   {'bbox': [376, 182, 10, 14],
#    'area': 140,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[378,
#      182,
#      378,
#      183,
#      377,
#      184,
#      377,
#      185,
#      376,
#      186,
#      376,
#      187,
#      377,
#      188,
#      377,
#      190,
#      378,
#      191,
#      378,
#      192,
#      379,
#      193,
#      379,
#      194,
#      380,
#      195,
#      383,
#      195,
#      384,
#      194,
#      384,
#      192,
#      385,
#      191,
#      385,
#      188,
#      384,
#      187,
#      384,
#      186,
#      383,
#      185,
#      383,
#      184,
#      381,
#      182]],
#    'category_id': 1},
#   {'bbox': [438, 503, 18, 9],
#    'area': 162,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[445,
#      503,
#      444,
#      504,
#      442,
#      504,
#      440,
#      506,
#      440,
#      507,
#      438,
#      509,
#      438,
#      511,
#      455,
#      511,
#      455,
#      509,
#      454,
#      508,
#      454,
#      507,
#      452,
#      505,
#      451,
#      505,
#      450,
#      504,
#      448,
#      504,
#      447,
#      503]],
#    'category_id': 1},
#   {'bbox': [12, 463, 9, 10],
#    'area': 90,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[16,
#      463,
#      15,
#      464,
#      14,
#      464,
#      12,
#      466,
#      12,
#      470,
#      14,
#      472,
#      18,
#      472,
#      20,
#      470,
#      20,
#      465,
#      18,
#      463]],
#    'category_id': 1},
#   {'bbox': [10, 338, 11, 12],
#    'area': 132,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[13,
#      338,
#      12,
#      339,
#      11,
#      339,
#      10,
#      340,
#      10,
#      346,
#      12,
#      348,
#      14,
#      348,
#      15,
#      349,
#      17,
#      349,
#      18,
#      348,
#      19,
#      348,
#      20,
#      347,
#      20,
#      341,
#      18,
#      339,
#      16,
#      339,
#      15,
#      338]],
#    'category_id': 1},
#   {'bbox': [477, 179, 16, 14],
#    'area': 224,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[481,
#      179,
#      478,
#      182,
#      478,
#      183,
#      477,
#      184,
#      477,
#      186,
#      478,
#      187,
#      478,
#      188,
#      481,
#      191,
#      482,
#      191,
#      483,
#      192,
#      484,
#      192,
#      485,
#      191,
#      487,
#      191,
#      488,
#      190,
#      489,
#      190,
#      490,
#      189,
#      491,
#      189,
#      491,
#      188,
#      492,
#      187,
#      492,
#      182,
#      490,
#      180,
#      489,
#      180,
#      488,
#      179]],
#    'category_id': 1},
#   {'bbox': [270, 0, 26, 9],
#    'area': 234,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[270,
#      0,
#      270,
#      4,
#      273,
#      4,
#      274,
#      5,
#      275,
#      5,
#      277,
#      7,
#      278,
#      7,
#      279,
#      6,
#      282,
#      6,
#      284,
#      8,
#      286,
#      8,
#      287,
#      7,
#      288,
#      7,
#      290,
#      5,
#      291,
#      5,
#      292,
#      6,
#      294,
#      6,
#      295,
#      5,
#      295,
#      4,
#      292,
#      1,
#      292,
#      0]],
#    'category_id': 1},
#   {'bbox': [433, 143, 8, 8],
#    'area': 64,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[436,
#      143,
#      435,
#      144,
#      434,
#      144,
#      433,
#      145,
#      433,
#      149,
#      434,
#      149,
#      435,
#      150,
#      437,
#      150,
#      440,
#      147,
#      440,
#      144,
#      439,
#      143]],
#    'category_id': 1},
#   {'bbox': [271, 506, 12, 6],
#    'area': 72,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[276,
#      506,
#      275,
#      507,
#      273,
#      507,
#      271,
#      509,
#      271,
#      511,
#      282,
#      511,
#      281,
#      510,
#      281,
#      508,
#      280,
#      507,
#      278,
#      507,
#      277,
#      506]],
#    'category_id': 1},
#   {'bbox': [0, 425, 4, 9],
#    'area': 36,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[0,
#      425,
#      0,
#      433,
#      1,
#      433,
#      3,
#      431,
#      3,
#      429,
#      2,
#      428,
#      2,
#      426,
#      1,
#      425]],
#    'category_id': 1},
#   {'bbox': [188, 493, 12, 12],
#    'area': 144,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[190,
#      493,
#      188,
#      495,
#      188,
#      500,
#      189,
#      501,
#      189,
#      502,
#      191,
#      504,
#      194,
#      504,
#      196,
#      502,
#      197,
#      502,
#      197,
#      501,
#      198,
#      500,
#      198,
#      499,
#      199,
#      498,
#      199,
#      497,
#      198,
#      496,
#      198,
#      495,
#      197,
#      494,
#      196,
#      494,
#      195,
#      493]],
#    'category_id': 1},
#   {'bbox': [92, 240, 17, 17],
#    'area': 289,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[98,
#      240,
#      96,
#      242,
#      95,
#      242,
#      95,
#      243,
#      93,
#      245,
#      93,
#      246,
#      92,
#      247,
#      92,
#      249,
#      93,
#      250,
#      93,
#      252,
#      95,
#      254,
#      96,
#      254,
#      97,
#      255,
#      98,
#      255,
#      99,
#      256,
#      102,
#      256,
#      103,
#      255,
#      104,
#      255,
#      108,
#      251,
#      108,
#      247,
#      107,
#      246,
#      107,
#      244,
#      103,
#      240]],
#    'category_id': 1},
#   {'bbox': [21, 344, 11, 12],
#    'area': 132,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[26,
#      344,
#      25,
#      345,
#      24,
#      345,
#      22,
#      347,
#      22,
#      348,
#      21,
#      349,
#      21,
#      353,
#      22,
#      354,
#      23,
#      354,
#      24,
#      355,
#      27,
#      355,
#      28,
#      354,
#      29,
#      354,
#      30,
#      353,
#      30,
#      352,
#      31,
#      351,
#      31,
#      347,
#      29,
#      345,
#      28,
#      345,
#      27,
#      344]],
#    'category_id': 1},
#   {'bbox': [336, 14, 8, 8],
#    'area': 64,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[339,
#      14,
#      338,
#      15,
#      337,
#      15,
#      336,
#      16,
#      336,
#      19,
#      337,
#      20,
#      338,
#      20,
#      339,
#      21,
#      342,
#      21,
#      343,
#      20,
#      343,
#      16,
#      342,
#      15,
#      341,
#      15,
#      340,
#      14]],
#    'category_id': 1},
#   {'bbox': [217, 341, 9, 10],
#    'area': 90,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[220,
#      341,
#      219,
#      342,
#      218,
#      342,
#      218,
#      343,
#      217,
#      344,
#      217,
#      348,
#      218,
#      349,
#      219,
#      349,
#      220,
#      350,
#      222,
#      350,
#      224,
#      348,
#      224,
#      347,
#      225,
#      346,
#      225,
#      344,
#      224,
#      343,
#      224,
#      342,
#      223,
#      342,
#      222,
#      341]],
#    'category_id': 1},
#   {'bbox': [239, 111, 10, 9],
#    'area': 90,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[243,
#      111,
#      242,
#      112,
#      241,
#      112,
#      240,
#      113,
#      240,
#      114,
#      239,
#      115,
#      239,
#      116,
#      242,
#      119,
#      243,
#      118,
#      245,
#      118,
#      248,
#      115,
#      248,
#      113,
#      247,
#      112,
#      246,
#      112,
#      245,
#      111]],
#    'category_id': 1},
#   {'bbox': [166, 34, 11, 11],
#    'area': 121,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[169,
#      34,
#      168,
#      35,
#      167,
#      35,
#      167,
#      36,
#      166,
#      37,
#      166,
#      42,
#      168,
#      44,
#      173,
#      44,
#      175,
#      42,
#      175,
#      41,
#      176,
#      40,
#      175,
#      39,
#      175,
#      37,
#      173,
#      35,
#      172,
#      35,
#      171,
#      34]],
#    'category_id': 1},
#   {'bbox': [0, 336, 12, 18],
#    'area': 216,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[0,
#      336,
#      0,
#      353,
#      5,
#      353,
#      6,
#      352,
#      8,
#      352,
#      10,
#      350,
#      10,
#      349,
#      11,
#      348,
#      11,
#      346,
#      10,
#      345,
#      10,
#      342,
#      9,
#      341,
#      9,
#      340,
#      7,
#      338,
#      6,
#      338,
#      5,
#      337,
#      4,
#      337,
#      3,
#      336]],
#    'category_id': 1},
#   {'bbox': [410, 153, 15, 14],
#    'area': 210,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[415,
#      153,
#      411,
#      157,
#      411,
#      159,
#      410,
#      160,
#      411,
#      161,
#      411,
#      163,
#      413,
#      165,
#      414,
#      165,
#      415,
#      166,
#      418,
#      166,
#      419,
#      165,
#      420,
#      165,
#      421,
#      164,
#      422,
#      164,
#      423,
#      163,
#      423,
#      160,
#      424,
#      159,
#      424,
#      156,
#      421,
#      153]],
#    'category_id': 1},
#   {'bbox': [109, 361, 12, 12],
#    'area': 144,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[114,
#      361,
#      113,
#      362,
#      111,
#      362,
#      109,
#      364,
#      109,
#      368,
#      110,
#      369,
#      110,
#      370,
#      112,
#      372,
#      116,
#      372,
#      117,
#      371,
#      119,
#      371,
#      120,
#      370,
#      120,
#      366,
#      119,
#      365,
#      119,
#      364,
#      117,
#      362,
#      115,
#      362]],
#    'category_id': 1},
#   {'bbox': [326, 206, 16, 19],
#    'area': 304,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[336,
#      206,
#      335,
#      207,
#      334,
#      207,
#      333,
#      208,
#      332,
#      208,
#      329,
#      211,
#      328,
#      211,
#      328,
#      212,
#      326,
#      214,
#      326,
#      222,
#      328,
#      224,
#      333,
#      224,
#      334,
#      223,
#      335,
#      223,
#      336,
#      222,
#      337,
#      222,
#      338,
#      221,
#      338,
#      220,
#      340,
#      218,
#      340,
#      214,
#      341,
#      213,
#      341,
#      209,
#      339,
#      207,
#      338,
#      207,
#      337,
#      206]],
#    'category_id': 1},
#   {'bbox': [237, 59, 9, 10],
#    'area': 90,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[240,
#      59,
#      239,
#      60,
#      238,
#      60,
#      237,
#      61,
#      237,
#      66,
#      238,
#      67,
#      239,
#      67,
#      240,
#      68,
#      241,
#      68,
#      242,
#      67,
#      243,
#      67,
#      244,
#      66,
#      244,
#      65,
#      245,
#      64,
#      245,
#      62,
#      244,
#      61,
#      244,
#      60,
#      243,
#      60,
#      242,
#      59]],
#    'category_id': 1},
#   {'bbox': [439, 54, 12, 13],
#    'area': 156,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[443,
#      54,
#      442,
#      55,
#      441,
#      55,
#      439,
#      57,
#      439,
#      64,
#      440,
#      65,
#      441,
#      65,
#      442,
#      66,
#      445,
#      66,
#      446,
#      65,
#      447,
#      65,
#      448,
#      64,
#      449,
#      64,
#      450,
#      63,
#      450,
#      59,
#      448,
#      57,
#      448,
#      56,
#      447,
#      55,
#      446,
#      55,
#      445,
#      54]],
#    'category_id': 1},
#   {'bbox': [151, 259, 11, 10],
#    'area': 110,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[153,
#      259,
#      152,
#      260,
#      151,
#      260,
#      151,
#      266,
#      152,
#      267,
#      153,
#      267,
#      154,
#      268,
#      155,
#      268,
#      156,
#      267,
#      157,
#      267,
#      160,
#      264,
#      160,
#      263,
#      161,
#      262,
#      160,
#      261,
#      160,
#      260,
#      159,
#      260,
#      158,
#      259]],
#    'category_id': 1},
#   {'bbox': [250, 317, 12, 11],
#    'area': 132,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[254,
#      317,
#      253,
#      318,
#      252,
#      318,
#      251,
#      319,
#      251,
#      320,
#      250,
#      321,
#      250,
#      322,
#      251,
#      323,
#      251,
#      324,
#      254,
#      327,
#      257,
#      327,
#      258,
#      326,
#      259,
#      326,
#      260,
#      325,
#      260,
#      324,
#      261,
#      323,
#      261,
#      321,
#      257,
#      317]],
#    'category_id': 1},
#   {'bbox': [327, 17, 11, 13],
#    'area': 143,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[330,
#      17,
#      329,
#      18,
#      328,
#      18,
#      328,
#      19,
#      327,
#      20,
#      327,
#      24,
#      328,
#      25,
#      328,
#      26,
#      329,
#      27,
#      330,
#      27,
#      331,
#      28,
#      332,
#      28,
#      333,
#      29,
#      334,
#      29,
#      335,
#      28,
#      336,
#      28,
#      336,
#      27,
#      337,
#      26,
#      337,
#      22,
#      336,
#      21,
#      336,
#      20,
#      335,
#      19,
#      335,
#      18,
#      334,
#      18,
#      333,
#      17]],
#    'category_id': 1},
#   {'bbox': [170, 214, 15, 14],
#    'area': 210,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[174,
#      214,
#      173,
#      215,
#      172,
#      215,
#      170,
#      217,
#      170,
#      222,
#      175,
#      227,
#      180,
#      227,
#      181,
#      226,
#      182,
#      226,
#      183,
#      225,
#      183,
#      223,
#      184,
#      222,
#      183,
#      221,
#      183,
#      220,
#      182,
#      219,
#      182,
#      218,
#      181,
#      217,
#      180,
#      217,
#      178,
#      215,
#      176,
#      215,
#      175,
#      214]],
#    'category_id': 1},
#   {'bbox': [306, 23, 9, 10],
#    'area': 90,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[309,
#      23,
#      307,
#      25,
#      307,
#      26,
#      306,
#      27,
#      306,
#      29,
#      307,
#      30,
#      307,
#      31,
#      308,
#      31,
#      309,
#      32,
#      311,
#      32,
#      312,
#      31,
#      313,
#      31,
#      314,
#      30,
#      314,
#      25,
#      313,
#      24,
#      313,
#      23]],
#    'category_id': 1},
#   {'bbox': [452, 0, 19, 10],
#    'area': 190,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[452,
#      0,
#      452,
#      1,
#      454,
#      3,
#      455,
#      3,
#      458,
#      6,
#      458,
#      7,
#      459,
#      7,
#      461,
#      9,
#      464,
#      9,
#      466,
#      7,
#      466,
#      6,
#      469,
#      3,
#      469,
#      1,
#      470,
#      0]],
#    'category_id': 1},
#   {'bbox': [113, 37, 6, 6],
#    'area': 36,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[114,
#      37,
#      113,
#      38,
#      113,
#      41,
#      114,
#      42,
#      116,
#      42,
#      118,
#      40,
#      118,
#      38,
#      117,
#      37]],
#    'category_id': 1},
#   {'bbox': [0, 341, 6, 13],
#    'area': 78,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[0,
#      341,
#      0,
#      353,
#      2,
#      353,
#      2,
#      352,
#      4,
#      350,
#      4,
#      349,
#      5,
#      348,
#      5,
#      345,
#      3,
#      343,
#      3,
#      342,
#      2,
#      342,
#      1,
#      341]],
#    'category_id': 1},
#   {'bbox': [132, 350, 10, 9],
#    'area': 90,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[136,
#      350,
#      135,
#      351,
#      134,
#      351,
#      132,
#      353,
#      132,
#      356,
#      134,
#      358,
#      139,
#      358,
#      140,
#      357,
#      140,
#      356,
#      141,
#      355,
#      141,
#      353,
#      138,
#      350]],
#    'category_id': 1},
#   {'bbox': [499, 339, 13, 13],
#    'area': 169,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[502,
#      339,
#      500,
#      341,
#      500,
#      342,
#      499,
#      343,
#      499,
#      346,
#      500,
#      347,
#      500,
#      349,
#      502,
#      351,
#      506,
#      351,
#      507,
#      350,
#      508,
#      350,
#      510,
#      348,
#      511,
#      348,
#      511,
#      342,
#      510,
#      341,
#      509,
#      341,
#      507,
#      339]],
#    'category_id': 1},
#   {'bbox': [137, 99, 12, 12],
#    'area': 144,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[141,
#      99,
#      140,
#      100,
#      139,
#      100,
#      138,
#      101,
#      138,
#      102,
#      137,
#      103,
#      137,
#      107,
#      140,
#      110,
#      143,
#      110,
#      144,
#      109,
#      145,
#      109,
#      147,
#      107,
#      147,
#      106,
#      148,
#      105,
#      148,
#      103,
#      147,
#      102,
#      147,
#      101,
#      146,
#      100,
#      145,
#      100,
#      144,
#      99]],
#    'category_id': 1},
#   {'bbox': [419, 219, 10, 11],
#    'area': 110,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[423,
#      219,
#      422,
#      220,
#      421,
#      220,
#      419,
#      222,
#      419,
#      227,
#      421,
#      229,
#      424,
#      229,
#      428,
#      225,
#      428,
#      221,
#      427,
#      220,
#      426,
#      220,
#      425,
#      219]],
#    'category_id': 1},
#   {'bbox': [75, 415, 24, 22],
#    'area': 528,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[84,
#      415,
#      83,
#      416,
#      82,
#      416,
#      81,
#      417,
#      80,
#      417,
#      76,
#      421,
#      76,
#      422,
#      75,
#      423,
#      75,
#      428,
#      76,
#      429,
#      76,
#      430,
#      77,
#      430,
#      78,
#      431,
#      78,
#      432,
#      82,
#      436,
#      90,
#      436,
#      96,
#      430,
#      96,
#      429,
#      97,
#      428,
#      97,
#      427,
#      98,
#      426,
#      98,
#      423,
#      97,
#      422,
#      97,
#      421,
#      96,
#      421,
#      94,
#      419,
#      93,
#      419,
#      91,
#      417,
#      90,
#      417,
#      89,
#      416,
#      88,
#      416,
#      87,
#      415]],
#    'category_id': 1},
#   {'bbox': [3, 223, 13, 13],
#    'area': 169,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[7,
#      223,
#      6,
#      224,
#      5,
#      224,
#      3,
#      226,
#      3,
#      229,
#      4,
#      230,
#      4,
#      232,
#      5,
#      233,
#      5,
#      234,
#      6,
#      235,
#      10,
#      235,
#      11,
#      234,
#      12,
#      234,
#      15,
#      231,
#      15,
#      225,
#      14,
#      225,
#      13,
#      224,
#      12,
#      224,
#      11,
#      223]],
#    'category_id': 1},
#   {'bbox': [203, 415, 13, 13],
#    'area': 169,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[210,
#      415,
#      209,
#      416,
#      206,
#      416,
#      204,
#      418,
#      204,
#      419,
#      203,
#      420,
#      203,
#      421,
#      204,
#      422,
#      204,
#      423,
#      206,
#      425,
#      206,
#      426,
#      207,
#      426,
#      208,
#      427,
#      212,
#      427,
#      213,
#      426,
#      214,
#      426,
#      214,
#      425,
#      215,
#      424,
#      215,
#      422,
#      214,
#      421,
#      214,
#      419,
#      213,
#      418,
#      213,
#      417,
#      212,
#      416,
#      211,
#      416]],
#    'category_id': 1},
#   {'bbox': [47, 29, 10, 10],
#    'area': 100,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[50,
#      29,
#      48,
#      31,
#      48,
#      32,
#      47,
#      33,
#      47,
#      35,
#      48,
#      36,
#      48,
#      37,
#      49,
#      37,
#      50,
#      38,
#      53,
#      38,
#      55,
#      36,
#      55,
#      35,
#      56,
#      34,
#      56,
#      32,
#      55,
#      31,
#      55,
#      30,
#      54,
#      29]],
#    'category_id': 1},
#   {'bbox': [495, 497, 11, 12],
#    'area': 132,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[500,
#      497,
#      499,
#      498,
#      498,
#      498,
#      497,
#      499,
#      496,
#      499,
#      496,
#      500,
#      495,
#      501,
#      495,
#      504,
#      498,
#      507,
#      499,
#      507,
#      500,
#      508,
#      502,
#      508,
#      505,
#      505,
#      505,
#      501,
#      504,
#      500,
#      504,
#      499,
#      503,
#      499,
#      502,
#      498,
#      501,
#      498]],
#    'category_id': 1},
#   {'bbox': [440, 203, 10, 9],
#    'area': 90,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[442,
#      203,
#      440,
#      205,
#      440,
#      208,
#      442,
#      210,
#      443,
#      210,
#      444,
#      211,
#      446,
#      211,
#      447,
#      210,
#      448,
#      210,
#      448,
#      209,
#      449,
#      208,
#      449,
#      205,
#      447,
#      203]],
#    'category_id': 1},
#   {'bbox': [156, 167, 13, 12],
#    'area': 156,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[159,
#      167,
#      156,
#      170,
#      156,
#      174,
#      157,
#      175,
#      157,
#      176,
#      158,
#      177,
#      159,
#      177,
#      160,
#      178,
#      162,
#      178,
#      163,
#      177,
#      165,
#      177,
#      167,
#      175,
#      167,
#      174,
#      168,
#      173,
#      168,
#      171,
#      167,
#      170,
#      167,
#      169,
#      165,
#      167]],
#    'category_id': 1},
#   {'bbox': [194, 450, 7, 7],
#    'area': 49,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[195,
#      450,
#      194,
#      451,
#      194,
#      454,
#      195,
#      455,
#      195,
#      456,
#      198,
#      456,
#      200,
#      454,
#      200,
#      452,
#      198,
#      450]],
#    'category_id': 1},
#   {'bbox': [77, 449, 11, 11],
#    'area': 121,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[79,
#      449,
#      78,
#      450,
#      78,
#      451,
#      77,
#      452,
#      78,
#      453,
#      78,
#      457,
#      80,
#      459,
#      83,
#      459,
#      86,
#      456,
#      86,
#      455,
#      87,
#      454,
#      87,
#      453,
#      86,
#      452,
#      86,
#      451,
#      84,
#      449]],
#    'category_id': 1},
#   {'bbox': [0, 8, 12, 12],
#    'area': 144,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[6,
#      8,
#      5,
#      9,
#      3,
#      9,
#      2,
#      10,
#      0,
#      10,
#      0,
#      17,
#      2,
#      17,
#      4,
#      19,
#      8,
#      19,
#      9,
#      18,
#      10,
#      18,
#      10,
#      17,
#      11,
#      16,
#      11,
#      11,
#      9,
#      9,
#      8,
#      9,
#      7,
#      8]],
#    'category_id': 1},
#   {'bbox': [0, 503, 8, 9],
#    'area': 72,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[0, 503, 0, 511, 7, 511, 7, 504, 6, 503]],
#    'category_id': 1},
#   {'bbox': [288, 98, 12, 9],
#    'area': 108,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[293,
#      98,
#      292,
#      99,
#      291,
#      99,
#      288,
#      102,
#      288,
#      104,
#      289,
#      105,
#      290,
#      105,
#      291,
#      106,
#      296,
#      106,
#      299,
#      103,
#      299,
#      101,
#      297,
#      99,
#      296,
#      99,
#      295,
#      98]],
#    'category_id': 1},
#   {'bbox': [62, 93, 9, 8],
#    'area': 72,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[64,
#      93,
#      62,
#      95,
#      62,
#      98,
#      63,
#      98,
#      64,
#      99,
#      65,
#      99,
#      66,
#      100,
#      68,
#      100,
#      70,
#      98,
#      70,
#      96,
#      69,
#      95,
#      69,
#      94,
#      68,
#      94,
#      67,
#      93]],
#    'category_id': 1},
#   {'bbox': [247, 241, 19, 17],
#    'area': 323,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[257,
#      241,
#      256,
#      242,
#      253,
#      242,
#      252,
#      243,
#      250,
#      243,
#      249,
#      244,
#      249,
#      245,
#      248,
#      246,
#      248,
#      248,
#      247,
#      249,
#      247,
#      252,
#      251,
#      256,
#      257,
#      256,
#      258,
#      257,
#      259,
#      257,
#      260,
#      256,
#      262,
#      256,
#      264,
#      254,
#      264,
#      253,
#      265,
#      252,
#      265,
#      250,
#      264,
#      249,
#      264,
#      247,
#      263,
#      246,
#      263,
#      245,
#      261,
#      243,
#      260,
#      243,
#      259,
#      242,
#      258,
#      242]],
#    'category_id': 1},
#   {'bbox': [313, 220, 11, 12],
#    'area': 132,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[317,
#      220,
#      316,
#      221,
#      315,
#      221,
#      314,
#      222,
#      314,
#      223,
#      313,
#      224,
#      313,
#      227,
#      314,
#      228,
#      314,
#      229,
#      316,
#      231,
#      319,
#      231,
#      320,
#      230,
#      321,
#      230,
#      323,
#      228,
#      323,
#      223,
#      321,
#      221,
#      320,
#      221,
#      319,
#      220]],
#    'category_id': 1},
#   {'bbox': [174, 417, 8, 8],
#    'area': 64,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[176,
#      417,
#      175,
#      418,
#      174,
#      418,
#      174,
#      422,
#      175,
#      423,
#      177,
#      423,
#      178,
#      424,
#      179,
#      424,
#      181,
#      422,
#      181,
#      420,
#      179,
#      418,
#      178,
#      418,
#      177,
#      417]],
#    'category_id': 1},
#   {'bbox': [52, 235, 15, 19],
#    'area': 285,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[55,
#      235,
#      52,
#      238,
#      52,
#      247,
#      57,
#      252,
#      58,
#      252,
#      59,
#      253,
#      63,
#      253,
#      65,
#      251,
#      65,
#      250,
#      66,
#      249,
#      66,
#      243,
#      65,
#      242,
#      65,
#      241,
#      64,
#      240,
#      64,
#      239,
#      62,
#      237,
#      61,
#      237,
#      60,
#      236,
#      59,
#      236,
#      58,
#      235]],
#    'category_id': 1},
#   {'bbox': [473, 399, 39, 34],
#    'area': 1326,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[489,
#      399,
#      488,
#      400,
#      484,
#      400,
#      483,
#      401,
#      482,
#      401,
#      477,
#      406,
#      476,
#      406,
#      475,
#      407,
#      474,
#      407,
#      474,
#      408,
#      473,
#      409,
#      473,
#      412,
#      474,
#      413,
#      474,
#      414,
#      475,
#      415,
#      475,
#      416,
#      476,
#      417,
#      476,
#      419,
#      475,
#      420,
#      475,
#      421,
#      474,
#      422,
#      474,
#      426,
#      476,
#      428,
#      478,
#      428,
#      479,
#      429,
#      481,
#      429,
#      482,
#      430,
#      484,
#      430,
#      485,
#      431,
#      493,
#      431,
#      494,
#      432,
#      504,
#      432,
#      506,
#      430,
#      506,
#      429,
#      507,
#      428,
#      507,
#      427,
#      508,
#      426,
#      508,
#      425,
#      509,
#      424,
#      510,
#      424,
#      511,
#      423,
#      511,
#      414,
#      510,
#      414,
#      508,
#      412,
#      508,
#      411,
#      507,
#      410,
#      507,
#      407,
#      506,
#      406,
#      506,
#      404,
#      504,
#      402,
#      503,
#      402,
#      502,
#      401,
#      500,
#      401,
#      499,
#      400,
#      497,
#      400,
#      496,
#      399]],
#    'category_id': 1},
#   {'bbox': [316, 458, 11, 12],
#    'area': 132,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[320,
#      458,
#      317,
#      461,
#      317,
#      462,
#      316,
#      463,
#      316,
#      466,
#      318,
#      468,
#      320,
#      468,
#      321,
#      469,
#      322,
#      468,
#      324,
#      468,
#      326,
#      466,
#      326,
#      463,
#      325,
#      462,
#      325,
#      461,
#      323,
#      459,
#      322,
#      459,
#      321,
#      458]],
#    'category_id': 1},
#   {'bbox': [474, 142, 11, 12],
#    'area': 132,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[477,
#      142,
#      475,
#      144,
#      475,
#      145,
#      474,
#      146,
#      474,
#      151,
#      476,
#      153,
#      481,
#      153,
#      482,
#      152,
#      483,
#      152,
#      484,
#      151,
#      484,
#      146,
#      483,
#      145,
#      483,
#      144,
#      482,
#      144,
#      481,
#      143,
#      479,
#      143,
#      478,
#      142]],
#    'category_id': 1},
#   {'bbox': [128, 94, 10, 9],
#    'area': 90,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[130,
#      94,
#      129,
#      95,
#      129,
#      96,
#      128,
#      97,
#      128,
#      100,
#      129,
#      101,
#      129,
#      102,
#      135,
#      102,
#      137,
#      100,
#      137,
#      97,
#      134,
#      94]],
#    'category_id': 1},
#   {'bbox': [264, 352, 16, 14],
#    'area': 224,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[270,
#      352,
#      269,
#      353,
#      268,
#      353,
#      267,
#      354,
#      266,
#      354,
#      264,
#      356,
#      264,
#      359,
#      265,
#      360,
#      265,
#      361,
#      266,
#      362,
#      266,
#      363,
#      267,
#      364,
#      268,
#      364,
#      269,
#      365,
#      273,
#      365,
#      274,
#      364,
#      277,
#      364,
#      278,
#      363,
#      278,
#      361,
#      279,
#      360,
#      279,
#      358,
#      278,
#      357,
#      278,
#      356,
#      277,
#      355,
#      277,
#      354,
#      276,
#      353,
#      275,
#      353,
#      274,
#      352]],
#    'category_id': 1},
#   {'bbox': [142, 196, 11, 9],
#    'area': 99,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[146,
#      196,
#      145,
#      197,
#      144,
#      197,
#      142,
#      199,
#      142,
#      201,
#      143,
#      202,
#      144,
#      202,
#      145,
#      203,
#      146,
#      203,
#      147,
#      204,
#      150,
#      204,
#      152,
#      202,
#      152,
#      198,
#      150,
#      196]],
#    'category_id': 1},
#   {'bbox': [336, 300, 6, 7],
#    'area': 42,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[337,
#      300,
#      336,
#      301,
#      336,
#      304,
#      337,
#      305,
#      337,
#      306,
#      340,
#      306,
#      341,
#      305,
#      341,
#      301,
#      340,
#      300]],
#    'category_id': 1},
#   {'bbox': [188, 499, 31, 13],
#    'area': 403,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[203,
#      499,
#      202,
#      500,
#      197,
#      500,
#      196,
#      501,
#      196,
#      502,
#      197,
#      503,
#      197,
#      505,
#      196,
#      506,
#      192,
#      506,
#      189,
#      509,
#      189,
#      510,
#      188,
#      511,
#      218,
#      511,
#      218,
#      509,
#      217,
#      508,
#      217,
#      507,
#      215,
#      505,
#      215,
#      503,
#      214,
#      502,
#      214,
#      501,
#      213,
#      500,
#      212,
#      501,
#      208,
#      501,
#      207,
#      500,
#      206,
#      500,
#      205,
#      499]],
#    'category_id': 1},
#   {'bbox': [259, 184, 10, 9],
#    'area': 90,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[260,
#      184,
#      259,
#      185,
#      259,
#      189,
#      260,
#      190,
#      260,
#      191,
#      261,
#      191,
#      262,
#      192,
#      266,
#      192,
#      268,
#      190,
#      268,
#      187,
#      266,
#      185,
#      264,
#      185,
#      263,
#      184]],
#    'category_id': 1},
#   {'bbox': [499, 412, 13, 12],
#    'area': 156,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[502,
#      412,
#      501,
#      413,
#      501,
#      414,
#      500,
#      415,
#      500,
#      416,
#      499,
#      417,
#      499,
#      420,
#      501,
#      422,
#      502,
#      422,
#      503,
#      423,
#      508,
#      423,
#      509,
#      422,
#      511,
#      422,
#      511,
#      413,
#      509,
#      413,
#      508,
#      412]],
#    'category_id': 1},
#   {'bbox': [252, 102, 14, 14],
#    'area': 196,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[258,
#      102,
#      257,
#      103,
#      256,
#      103,
#      255,
#      104,
#      254,
#      104,
#      254,
#      105,
#      253,
#      106,
#      253,
#      107,
#      252,
#      108,
#      252,
#      111,
#      253,
#      112,
#      253,
#      113,
#      255,
#      115,
#      261,
#      115,
#      265,
#      111,
#      265,
#      106,
#      262,
#      103,
#      261,
#      103,
#      260,
#      102]],
#    'category_id': 1},
#   {'bbox': [388, 93, 14, 13],
#    'area': 182,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[395,
#      93,
#      394,
#      94,
#      392,
#      94,
#      389,
#      97,
#      389,
#      99,
#      388,
#      100,
#      389,
#      101,
#      389,
#      102,
#      391,
#      104,
#      392,
#      104,
#      393,
#      105,
#      397,
#      105,
#      398,
#      104,
#      399,
#      104,
#      399,
#      103,
#      400,
#      102,
#      400,
#      101,
#      401,
#      100,
#      401,
#      97,
#      398,
#      94,
#      397,
#      94,
#      396,
#      93]],
#    'category_id': 1},
#   {'bbox': [461, 0, 7, 10],
#    'area': 70,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[462,
#      0,
#      462,
#      2,
#      461,
#      3,
#      461,
#      7,
#      462,
#      8,
#      464,
#      8,
#      465,
#      9,
#      467,
#      7,
#      467,
#      0]],
#    'category_id': 1},
#   {'bbox': [111, 309, 9, 7],
#    'area': 63,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[113,
#      309,
#      112,
#      310,
#      112,
#      311,
#      111,
#      312,
#      111,
#      313,
#      113,
#      315,
#      117,
#      315,
#      119,
#      313,
#      119,
#      310,
#      118,
#      309]],
#    'category_id': 1},
#   {'bbox': [444, 0, 21, 10],
#    'area': 210,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[444,
#      0,
#      444,
#      4,
#      445,
#      5,
#      445,
#      6,
#      448,
#      9,
#      453,
#      9,
#      454,
#      8,
#      459,
#      8,
#      460,
#      7,
#      461,
#      7,
#      462,
#      6,
#      462,
#      5,
#      463,
#      4,
#      463,
#      2,
#      464,
#      1,
#      464,
#      0]],
#    'category_id': 1},
#   {'bbox': [426, 56, 11, 10],
#    'area': 110,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[429,
#      56,
#      428,
#      57,
#      427,
#      57,
#      426,
#      58,
#      426,
#      62,
#      429,
#      65,
#      433,
#      65,
#      436,
#      62,
#      436,
#      57,
#      435,
#      57,
#      434,
#      56]],
#    'category_id': 1},
#   {'bbox': [202, 83, 13, 12],
#    'area': 156,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[206,
#      83,
#      205,
#      84,
#      204,
#      84,
#      203,
#      85,
#      203,
#      86,
#      202,
#      87,
#      202,
#      90,
#      205,
#      93,
#      206,
#      93,
#      207,
#      94,
#      210,
#      94,
#      211,
#      93,
#      212,
#      93,
#      214,
#      91,
#      214,
#      88,
#      213,
#      87,
#      213,
#      86,
#      211,
#      84,
#      210,
#      84,
#      209,
#      83]],
#    'category_id': 1},
#   {'bbox': [127, 43, 15, 14],
#    'area': 210,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[133,
#      43,
#      132,
#      44,
#      131,
#      44,
#      130,
#      45,
#      129,
#      45,
#      127,
#      47,
#      127,
#      52,
#      131,
#      56,
#      135,
#      56,
#      136,
#      55,
#      137,
#      55,
#      140,
#      52,
#      140,
#      51,
#      141,
#      50,
#      141,
#      48,
#      140,
#      47,
#      140,
#      46,
#      138,
#      44,
#      137,
#      44,
#      136,
#      43]],
#    'category_id': 1},
#   {'bbox': [225, 462, 7, 9],
#    'area': 63,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[227,
#      462,
#      225,
#      464,
#      225,
#      467,
#      228,
#      470,
#      230,
#      470,
#      230,
#      469,
#      231,
#      468,
#      231,
#      464,
#      229,
#      462]],
#    'category_id': 1},
#   {'bbox': [507, 47, 5, 9],
#    'area': 45,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[509,
#      47,
#      507,
#      49,
#      507,
#      51,
#      508,
#      52,
#      508,
#      53,
#      509,
#      54,
#      510,
#      54,
#      511,
#      55,
#      511,
#      47]],
#    'category_id': 1},
#   {'bbox': [167, 144, 8, 11],
#    'area': 88,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[168,
#      144,
#      167,
#      145,
#      167,
#      150,
#      168,
#      151,
#      168,
#      152,
#      170,
#      154,
#      173,
#      154,
#      174,
#      153,
#      174,
#      148,
#      173,
#      147,
#      173,
#      146,
#      171,
#      144]],
#    'category_id': 1},
#   {'bbox': [340, 191, 11, 10],
#    'area': 110,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[343,
#      191,
#      340,
#      194,
#      340,
#      198,
#      341,
#      199,
#      343,
#      199,
#      344,
#      200,
#      347,
#      200,
#      349,
#      198,
#      349,
#      197,
#      350,
#      196,
#      350,
#      194,
#      347,
#      191]],
#    'category_id': 1},
#   {'bbox': [360, 171, 17, 19],
#    'area': 323,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[366,
#      171,
#      365,
#      172,
#      364,
#      172,
#      361,
#      175,
#      361,
#      177,
#      360,
#      178,
#      360,
#      181,
#      361,
#      182,
#      361,
#      183,
#      367,
#      189,
#      369,
#      189,
#      371,
#      187,
#      372,
#      187,
#      374,
#      185,
#      374,
#      184,
#      375,
#      183,
#      375,
#      181,
#      376,
#      180,
#      375,
#      179,
#      375,
#      177,
#      374,
#      176,
#      374,
#      174,
#      372,
#      172,
#      371,
#      172,
#      370,
#      171]],
#    'category_id': 1},
#   {'bbox': [99, 309, 11, 10],
#    'area': 110,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[101,
#      309,
#      101,
#      310,
#      100,
#      311,
#      100,
#      312,
#      99,
#      313,
#      99,
#      315,
#      101,
#      317,
#      102,
#      317,
#      103,
#      318,
#      107,
#      318,
#      108,
#      317,
#      108,
#      316,
#      109,
#      315,
#      109,
#      314,
#      108,
#      313,
#      108,
#      311,
#      106,
#      309]],
#    'category_id': 1},
#   {'bbox': [98, 256, 8, 9],
#    'area': 72,
#    'bbox_mode': <BoxMode.XYWH_ABS: 1>,
#    'segmentation': [[100,
#      256,
#      98,
#      258,
#      98,
#      263,
#      99,
#      264,
#      101,
#      264,
#      102,
#      263,
#      103,
#      263,
#      105,
#      261,
#      105,
#      258,
#      104,
#      257,
#      104,
#      256]],
#    'category_id': 1}]}

# %%
#! rm /home/shared/hsc/HSC/HSC_DR3/data/test.json
#! rm /home/shared/hsc/HSC/HSC_DR3/data/test.json.lock

# %%
dirpath
# Out:
# '/home/shared/hsc/decam/decam_data/'

# %%
#convert_to_coco_json('astro_train', os.path.join(dirpath,'train.json'), allow_cached=True)

convert_to_json(dataset_dicts['train'], 'astro_train', os.path.join(dirpath,'train.json'), allow_cached=False)
convert_to_json(dataset_dicts['test'], 'astro_test', os.path.join(dirpath,'test.json'), allow_cached=False)
convert_to_json(dataset_dicts['val'], 'astro_val', os.path.join(dirpath,'val.json'), allow_cached=False)
# Out:
# Caching COCO format annotations at '/home/shared/hsc/decam/decam_data/train.json' ...
# Caching COCO format annotations at '/home/shared/hsc/decam/decam_data/test.json' ...
# Caching COCO format annotations at '/home/shared/hsc/decam/decam_data/val.json' ...

# %%
def get_data_from_json(file):
    # Opening JSON file
    with open(file, 'r') as f:
        data = json.load(f)
    return data

# %%
trainfile='/home/shared/hsc/decam/decam_data/train.json'

td = get_data_from_json(trainfile)

# %%
# Out:
# 1000
